# %%
import pathlib
from src.parsing.pdf_text import extract_text_from_pdf

# Input and output folders
input_folder = pathlib.Path(r"C:\\Users\\aayus\\Dev\\CV-Analyzer\\data\\resumes_raw")
output_folder = pathlib.Path(r"C:\\Users\\aayus\\Dev\\CV-Analyzer\\data\\resumes_text")
output_folder.mkdir(parents=True, exist_ok=True)

# Loop over all PDFs in the input folder
for pdf_file in input_folder.glob("*.pdf"):
    output_file = output_folder / f"{pdf_file.stem}.txt"
    text = extract_text_from_pdf(pdf_file, output_file)

from src.parsing.docx_text import extract_text_from_docx

for docx_file in input_folder.glob("*.docx"):
    output_file = output_folder / f"{docx_file.stem}.txt"
    text = extract_text_from_docx(docx_file, output_file)

# %%
from src.parsing.resume_parser import parse_resume

for file in output_folder.iterdir(): # only PDFs and DOCX
        print(file)
        parsed = parse_resume(str(file))
        print(f"{file.name}: {parsed}")
# Out:
# C:\Users\aayus\Dev\CV-Analyzer\data\resumes_text\Amit_Jangir.txt
# <re.Match object; span=(145, 172), match='skills, hands-on experience'>
# Amit_Jangir.txt: {'name': None, 'email': None, 'phone': None, 'education': ['B.Tech', 'BE', 'ME'], 'skills': ['hands', 'on']}
# C:\Users\aayus\Dev\CV-Analyzer\data\resumes_text\Ananya_Sharma.txt
# <re.Match object; span=(143, 170), match='skills, hands-on experience'>
# Ananya_Sharma.txt: {'name': None, 'email': None, 'phone': None, 'education': ['B.Tech', 'BE', 'ME', 'University'], 'skills': ['hands', 'on']}
# C:\Users\aayus\Dev\CV-Analyzer\data\resumes_text\CV_Aarav_Mehta.txt
# <re.Match object; span=(279, 451), match='Skills JavaScript, React, Node.js, Python, SQL, A>
# CV_Aarav_Mehta.txt: {'name': None, 'email': 'aarav.mehta@gmail.com', 'phone': '+91 9876543210', 'education': ['B.Tech', 'BE', 'ME'], 'skills': ['JavaScript', 'React', 'Node.js', 'Python', 'SQL', 'AWS', 'Git Problem Solving Skills Strong debugging skills', 'optimized database queries', 'designed scalable APIs. Work']}
# C:\Users\aayus\Dev\CV-Analyzer\data\resumes_text\CV_Arjun_Sharma.txt
# <re.Match object; span=(318, 495), match='Skills SEO, SEM, Google Analytics, Content Market>
# CV_Arjun_Sharma.txt: {'name': 'Email', 'email': 'arjun.sharma@gmail.com', 'phone': '+91 9988776655', 'education': ['BE', 'ME', 'MBA', 'University'], 'skills': ['SEO', 'SEM', 'Google Analytics', 'Content Marketing', 'Branding Problem Solving Skills Revamped marketing strategy leading to 40% increase in customer engagement. Work']}
# C:\Users\aayus\Dev\CV-Analyzer\data\resumes_text\CV_Priya_Gupta.txt
# <re.Match object; span=(276, 459), match='Skills AutoCAD, SolidWorks, MATLAB, CNC Machining>
# CV_Priya_Gupta.txt: {'name': None, 'email': 'priya.gupta@gmail.com', 'phone': '+91 9123456780', 'education': ['B.Tech', 'BE', 'ME'], 'skills': ['AutoCAD', 'SolidWorks', 'MATLAB', 'CNC Machining', 'Thermodynamics Problem Solving Skills Designed cost', 'efficient mechanical systems reducing manufacturing cost by 20%. Work']}
# C:\Users\aayus\Dev\CV-Analyzer\data\resumes_text\CV_Rahul_Verma.txt
# <re.Match object; span=(259, 412), match='Skills Figma, Adobe XD, Sketch, Wireframing, Prot>
# CV_Rahul_Verma.txt: {'name': None, 'email': 'rahul.verma@gmail.com', 'phone': '+91 9765432100', 'education': ['BE', 'ME'], 'skills': ['Figma', 'Adobe XD', 'Sketch', 'Wireframing', 'Prototyping Problem Solving Skills Redesigned user flows', 'reducing customer drop', 'off by 25%. Work']}
# C:\Users\aayus\Dev\CV-Analyzer\data\resumes_text\CV_Sara_Kapoor.txt
# <re.Match object; span=(342, 514), match='Skills Python, R, SQL, Tableau, Power BI, Excel P>
# CV_Sara_Kapoor.txt: {'name': 'Email', 'email': 'sara.kapoor@gmail.com', 'phone': '+91 9876501234', 'education': ['ME', 'M.Sc', 'MBA', 'University'], 'skills': ['Python', 'SQL', 'Tableau', 'Power BI', 'Excel Problem Solving Skills Built predictive models', 'automated reporting pipelines reducing manual effort by 40%. Work']}
# C:\Users\aayus\Dev\CV-Analyzer\data\resumes_text\David_Wilson.txt
# <re.Match object; span=(126, 153), match='skills, hands-on experience'>
# David_Wilson.txt: {'name': None, 'email': None, 'phone': None, 'education': ['B.Tech', 'BE', 'ME', 'University'], 'skills': ['hands', 'on']}
# C:\Users\aayus\Dev\CV-Analyzer\data\resumes_text\Emily_Johnson.txt
# <re.Match object; span=(139, 166), match='skills, hands-on experience'>
# Emily_Johnson.txt: {'name': None, 'email': None, 'phone': None, 'education': ['B.Tech', 'BE', 'ME', 'MBA'], 'skills': ['hands', 'on']}
# C:\Users\aayus\Dev\CV-Analyzer\data\resumes_text\James_Anderson.txt
# <re.Match object; span=(136, 163), match='skills, hands-on experience'>
# James_Anderson.txt: {'name': None, 'email': None, 'phone': None, 'education': ['B.Tech', 'BE', 'ME', 'MBA'], 'skills': ['hands', 'on']}
# C:\Users\aayus\Dev\CV-Analyzer\data\resumes_text\John_Miller.txt
# <re.Match object; span=(137, 164), match='skills, hands-on experience'>
# John_Miller.txt: {'name': None, 'email': None, 'phone': None, 'education': ['B.Tech', 'BE', 'ME'], 'skills': ['hands', 'on']}
# C:\Users\aayus\Dev\CV-Analyzer\data\resumes_text\Michael_Brown.txt
# <re.Match object; span=(139, 166), match='skills, hands-on experience'>
# Michael_Brown.txt: {'name': None, 'email': None, 'phone': None, 'education': ['B.Tech', 'BE', 'ME'], 'skills': ['hands', 'on']}
# C:\Users\aayus\Dev\CV-Analyzer\data\resumes_text\Neha_Gupta.txt
# <re.Match object; span=(144, 171), match='skills, hands-on experience'>
# Neha_Gupta.txt: {'name': None, 'email': None, 'phone': None, 'education': ['B.Tech', 'BE', 'ME', 'University'], 'skills': ['hands', 'on']}
# C:\Users\aayus\Dev\CV-Analyzer\data\resumes_text\Pooja_Purohit.txt
# <re.Match object; span=(147, 174), match='skills, hands-on experience'>
# Pooja_Purohit.txt: {'name': None, 'email': None, 'phone': None, 'education': ['B.Tech', 'BE', 'ME', 'University'], 'skills': ['hands', 'on']}
# C:\Users\aayus\Dev\CV-Analyzer\data\resumes_text\Rohit_Jha.txt
# <re.Match object; span=(129, 156), match='skills, hands-on experience'>
# Rohit_Jha.txt: {'name': None, 'email': None, 'phone': None, 'education': ['B.Tech', 'BE', 'ME', 'University'], 'skills': ['hands', 'on']}
# C:\Users\aayus\Dev\CV-Analyzer\data\resumes_text\Sarah_Davis.txt
# <re.Match object; span=(125, 152), match='skills, hands-on experience'>
# Sarah_Davis.txt: {'name': None, 'email': None, 'phone': None, 'education': ['B.Tech', 'BE', 'ME', 'University'], 'skills': ['hands', 'on']}
# C:\Users\aayus\Dev\CV-Analyzer\data\resumes_text\Vikas_Gurjar.txt
# <re.Match object; span=(142, 169), match='skills, hands-on experience'>
# Vikas_Gurjar.txt: {'name': None, 'email': None, 'phone': None, 'education': ['B.Tech', 'BE', 'ME'], 'skills': ['hands', 'on']}

# %%
from src.nlp.spacy_pipe import extract_entities, extract_person_names, quick_ner_summary
from src.parsing.resume_parser import parse_resume
import pathlib

input_folder = pathlib.Path(r"C:\\Users\\aayus\\Dev\\CV-Analyzer\\data\\resumes_raw")

for file in input_folder.iterdir():
    parsed = parse_resume(str(file))
    combined_text = " ".join(
        str(value) for value in parsed.values() if value
    )
    print(extract_person_names(combined_text))
    print(quick_ner_summary(combined_text))
    print(extract_entities(combined_text)[:20])
# Out:
# ['Kali Linux']
# {'PERSON': 1}
# [('Kali Linux', 'PERSON')]
# []
# {'ORG': 1}
# [('SQL', 'ORG')]
# ['Java']
# {'PERSON': 1, 'ORG': 1}
# [('Java', 'PERSON'), ('SQL', 'ORG')]
# ['Email arjun.sharma@gmail.com +91']
# {'PERSON': 1, 'DATE': 1, 'WORK_OF_ART': 1}
# [('Email arjun.sharma@gmail.com +91', 'PERSON'), ('9988776655', 'DATE'), ('MBA', 'WORK_OF_ART')]
# ['Priya Gupta']
# {'PERSON': 1}
# [('Priya Gupta', 'PERSON')]
# ['+91', 'Rahul Verma UX/']
# {'PERSON': 2, 'PRODUCT': 1}
# [('Rahul Verma UX/', 'PERSON'), ('+91', 'PERSON'), ('Excel', 'PRODUCT')]
# ['+91']
# {'PERSON': 1, 'DATE': 1, 'ORG': 1, 'PRODUCT': 1}
# [('+91', 'PERSON'), ('9876501234', 'DATE'), ('SQL', 'ORG'), ('Excel', 'PRODUCT')]
# ['David Wilson Role', 'Java', "Machine Learning'"]
# {'PERSON': 3}
# [('David Wilson Role', 'PERSON'), ('Java', 'PERSON'), ("Machine Learning'", 'PERSON')]
# ['Emily Johnson Role', 'Java']
# {'PERSON': 2, 'WORK_OF_ART': 1, 'ORG': 1}
# [('Emily Johnson Role', 'PERSON'), ('Java', 'PERSON'), ("C++'", 'WORK_OF_ART'), ('SQL', 'ORG')]
# ['James Anderson Role']
# {'PERSON': 1}
# [('James Anderson Role', 'PERSON')]
# ['Java', 'John Miller Role']
# {'PERSON': 2, 'WORK_OF_ART': 1, 'ORG': 1}
# [('John Miller Role', 'PERSON'), ('Java', 'PERSON'), ("C++'", 'WORK_OF_ART'), ('SQL', 'ORG')]
# ['Java', 'Michael Brown Role']
# {'PERSON': 2, 'WORK_OF_ART': 1, 'ORG': 1}
# [('Michael Brown Role', 'PERSON'), ('Java', 'PERSON'), ("C++'", 'WORK_OF_ART'), ('SQL', 'ORG')]
# ['Neha Gupta Role']
# {'PERSON': 1}
# [('Neha Gupta Role', 'PERSON')]
# ['Kali Linux']
# {'PERSON': 1}
# [('Kali Linux', 'PERSON')]
# ['Rohit Jha Role']
# {'PERSON': 1}
# [('Rohit Jha Role', 'PERSON')]
# ['Java', "Machine Learning'", 'Sarah Davis Role']
# {'PERSON': 3}
# [('Sarah Davis Role', 'PERSON'), ('Java', 'PERSON'), ("Machine Learning'", 'PERSON')]
# ['Java']
# {'ORG': 2, 'PERSON': 1}
# [('NIT', 'ORG'), ('Java', 'PERSON'), ('SQL', 'ORG')]

# %%
from src.nlp.skills import load_skills, compile_patterns, detect_skills

skills = load_skills("data/skills.csv")
print(skills)
patterns = compile_patterns(skills)
sample_text = """
Experienced Python and React developer with AWS and Docker.
Built REST APIs with Flask and PostgreSQL, CI/CD via GitHub Actions.
"""

print(detect_skills(sample_text, patterns))
# Expected: {'Python', 'React', 'AWS', 'Docker', 'REST API', 'Flask', 'PostgreSQL', 'CI/CD', 'Git'}
# Out:
# {'Python': ['cpython', 'py', 'python', 'python3'], 'Java': ['java', 'jdk', 'jre'], 'C++': ['c++', 'cpp'], 'C': ['c'], 'C#': ['c#', 'csharp'], 'JavaScript': ['ecmascript', 'javascript', 'js'], 'TypeScript': ['ts', 'typescript'], 'HTML': ['html', 'html5'], 'CSS': ['css', 'css3'], 'SQL': ['ansi sql', 'sql'], 'PostgreSQL': ['postgres', 'postgresql', 'psql'], 'MySQL': ['mysql'], 'SQLite': ['sqlite', 'sqlite3'], 'MongoDB': ['mongo', 'mongodb'], 'Redis': ['redis'], 'Django': ['django'], 'Flask': ['flask'], 'FastAPI': ['fastapi'], 'Spring': ['spring', 'spring boot', 'spring-boot'], 'Node.js': ['node', 'node.js', 'nodejs'], 'Express': ['express', 'express.js', 'expressjs'], 'React': ['react', 'react.js', 'reactjs'], 'Angular': ['angular', 'angular.js', 'angularjs'], 'Vue': ['vue', 'vue.js', 'vuejs'], 'Next.js': ['next', 'next.js', 'nextjs'], 'Tailwind CSS': ['tailwind', 'tailwind css', 'tailwindcss'], 'Bootstrap': ['bootstrap'], 'jQuery': ['jquery'], 'REST API': ['rest', 'rest api', 'restful'], 'GraphQL': ['graphql'], 'Git': ['bitbucket', 'git', 'github', 'gitlab'], 'Linux': ['linux', 'unix'], 'Docker': ['docker'], 'Kubernetes': ['k8s', 'kubernetes'], 'CI/CD': ['azure devops', 'ci cd', 'ci/cd', 'cicd', 'circleci', 'github actions', 'gitlab ci', 'jenkins'], 'AWS': ['amazon web services', 'aws', 'ec2', 'lambda', 'rds', 's3'], 'Azure': ['aks', 'app service', 'azure', 'microsoft azure'], 'GCP': ['bigquery', 'gcp', 'gke', 'google cloud'], 'NumPy': ['numpy'], 'Pandas': ['pandas'], 'scikit-learn': ['scikit-learn', 'sklearn'], 'TensorFlow': ['tensorflow', 'tf'], 'PyTorch': ['pytorch', 'torch'], 'Keras': ['keras'], 'NLTK': ['nltk'], 'spaCy': ['spacy'], 'Transformers': ['bert', 'distilbert', 'huggingface', 'roberta', 'transformers'], 'OpenCV': ['cv2', 'opencv'], 'Power BI': ['power bi', 'powerbi'], 'Tableau': ['tableau'], 'Excel': ['excel', 'microsoft excel', 'ms excel', 'spreadsheets'], 'Apache Spark': ['apache spark', 'pyspark', 'spark'], 'Hadoop': ['hadoop', 'hdfs', 'mapreduce'], 'Airflow': ['airflow', 'apache airflow'], 'Kafka': ['apache kafka', 'kafka'], 'Elasticsearch': ['elastic', 'elasticsearch'], 'MLflow': ['mlflow'], 'SQL Server': ['ms sql', 'mssql', 'sql server'], 'NoSQL': ['nosql']}
# {'React', 'REST API', 'AWS', 'Docker', 'PostgreSQL', 'Python', 'Git', 'CI/CD', 'Flask'}
